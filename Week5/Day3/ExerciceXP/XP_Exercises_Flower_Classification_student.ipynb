# %% [markdown]
# # XP Exercises: Flower Classification using CNN
#
# This is a guided notebook for the exercises on the platform. Cells marked **PREFILLED** are for execution only. Cells marked **To-Do** require your action. When a written answer is required, the **To-Do** appears inside a markdown cell. When code is required, the **To-Do** appears inside a code cell as comments.
#
# Learning points appear only for key concepts that unlock intuition or transfer to other ML topics.

# %% [markdown]
# ## What you will learn
# - Building a CNN for multi class image classification
# - Data loading and preprocessing with `image_dataset_from_directory`
# - Image visualization techniques
# - Model architecture design, compilation, and training
# - Evaluating model performance with accuracy and loss plots

# %% [markdown]
# ## What you will create
# A CNN model that classifies 14 flower species.
# All parts form one continuous exercise. Work through them sequentially.

# %% [markdown]
# ## Dataset
# **As stated in the exercises**
# Flower classification with 14 classes. Images are organized in class folders. A training and validation split may be provided. Images are resized to 256x256 in this notebook.
#
# **PREFILLED info**
# This notebook expects the provided zip file to be available. The code below extracts it and locates the dataset root automatically.

# %%
# PREFILLED: just execute
import os, sys, zipfile, shutil, glob, math, json, random
from pathlib import Path

# Find the dataset archive on the local filesystem, or fall back to common locations.
cwd = Path.cwd()
zip_candidates = [p for p in cwd.rglob("*.zip") if "flower" in p.name.lower()]
zip_candidates = sorted(set(zip_candidates))
if zip_candidates:
    DATA_ZIP = zip_candidates[0]
    print("Found dataset archive:", DATA_ZIP)
else:
    alt_paths = [
        Path("Flower Classification.zip"),
        Path("./flower_classification.zip"),
        Path("/content/Flower Classification.zip"),
        Path("/content/flower_classification.zip"),
        Path("/Data/Flower Classification.zip"),
        Path("/Data/flower_classification.zip"),
    ]
    DATA_ZIP = next((p for p in alt_paths if p.exists()), None)
    if DATA_ZIP is not None:
        print("Found dataset archive at fallback path:", DATA_ZIP)
    else:
        DATA_ZIP = Path("./Flower Classification.zip")
        print("No archive found in common locations. Using default path:", DATA_ZIP)

EXTRACT_DIR = Path("./data/flower_data")

# Clean extract dir if re-running
if EXTRACT_DIR.exists():
    pass  # avoid deleting in case you added files; delete manually if needed
else:
    EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

# Extract if a zip is present and not already extracted
if DATA_ZIP.exists():
    marker = EXTRACT_DIR / ".extracted"
    if not marker.exists():
        try:
            with zipfile.ZipFile(DATA_ZIP, 'r') as zf:
                zf.extractall(EXTRACT_DIR)
        except zipfile.BadZipFile:
            print("BadZipFile: the archive is not a valid zip file:", DATA_ZIP)
        else:
            marker.write_text("ok")
            print("Extracted:", DATA_ZIP.name, "->", EXTRACT_DIR)
    else:
        print("Already extracted. Skipping.")
else:
    print("Zip file not found at", DATA_ZIP)
    if zip_candidates:
        print("Zip candidates found in the workspace:")
        for p in zip_candidates:
            print(" -", p)

# Find candidate dataset roots: a dir with >= 10 subdirs assumed as classes, or contains train/val
def list_dirs(p):
    return [d for d in Path(p).iterdir() if d.is_dir()]

candidates = []
for root, dirs, files in os.walk(EXTRACT_DIR):
    root_path = Path(root)
    try:
        subdirs = [d for d in root_path.iterdir() if d.is_dir()]
    except PermissionError:
        continue
    if len(subdirs) >= 10:
        candidates.append(root_path)
    if "train" in [d.name.lower() for d in subdirs] and "val" in [d.name.lower() for d in subdirs]:
        candidates.append(root_path)

candidates = sorted(set(candidates))
print("Candidate dataset roots:", [str(c) for c in candidates][:5])
# Out:
# Found dataset archive: c:\Users\meles\Documents\TTA_DI_BootCamp_Gilles-Chris_MAKE\Week5\Day3\ExerciceXP\Flower Classification.zip
# Extracted: Flower Classification.zip -> data\flower_data
# Candidate dataset roots: ['data\\flower_data\\Data', 'data\\flower_data\\Data\\train', 'data\\flower_data\\Data\\val']

# %% [markdown]
# ## Part 1. Data exploration and visualization
#
# **As stated in the exercises**
# Load the dataset using `image_dataset_from_directory`. Print number of images per class. Modify `visualize_images` to show a 3x3 grid for each class with the class name as the grid title. Analyze challenges you anticipate when classifying the flowers such as similar colors or shapes and intra class variation.

# %% [markdown]
# **Guidance**
# If a `train` or `val` folder exists, use them. Otherwise create a split from a single root with `validation_split` and `subset`. Images are resized to 256x256 RGB.

# %% [markdown]
# > **IMPORTANT:** we fix a low resultion for images in IMG_SIZE=(32,32) for faster training, however you can change it if you want to test out other resolutions

# %%
# PREFILLED: just execute
# %pip install tensorflow
import tensorflow as tf
from tensorflow.keras import layers

IMG_SIZE = (32, 32)
BATCH_SIZE = 32
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

def detect_layout(root: Path):
    root = Path(root)
    sub = [d.name.lower() for d in root.iterdir() if d.is_dir()]
    if "train" in sub and "val" in sub:
        return "provided_split", root
    return "single_root", root

# Choose a root
if 'candidates' in globals() and len(candidates) > 0:
    DS_ROOT = candidates[0]
else:
    DS_ROOT = EXTRACT_DIR  # fallback

layout, base = detect_layout(DS_ROOT)
print("Layout:", layout, "Base:", base)
# Out:
# Requirement already satisfied: tensorflow in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (1.81.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (2.4.6)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\meles\documents\tta_di_bootcamp_gilles-chris_make\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Layout: provided_split Base: data\flower_data\Data
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# PREFILLED: just execute
def find_image_dataset_root(root):
    root = Path(root)
    valid_exts = {".jpg", ".jpeg", ".png", ".bmp", ".gif"}

    def contains_images(path):
        return any(p.is_file() and p.suffix.lower() in valid_exts for p in path.rglob("*"))

    def looks_like_dataset(path):
        subdirs = [d for d in path.iterdir() if d.is_dir()]
        return len(subdirs) >= 2 and contains_images(path)

    if looks_like_dataset(root):
        return root

    for child in root.iterdir():
        if child.is_dir() and looks_like_dataset(child):
            return child

    return root

dataset_root = find_image_dataset_root(base)
if dataset_root != base:
    print("Using nested dataset root:", dataset_root)

if layout == "provided_split":
    train_dir = next((p for p in dataset_root.iterdir() if p.name.lower() == "train"))
    val_dir = next((p for p in dataset_root.iterdir() if p.name.lower() == "val"))
    train_ds = tf.keras.utils.image_dataset_from_directory(
        train_dir, image_size=IMG_SIZE, batch_size=BATCH_SIZE, seed=SEED, label_mode="int"
    )
    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir, image_size=IMG_SIZE, batch_size=BATCH_SIZE, seed=SEED, label_mode="int"
    )
else:
    train_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_root, validation_split=0.2, subset="training", seed=SEED,
        image_size=IMG_SIZE, batch_size=BATCH_SIZE, label_mode="int"
    )
    val_ds = tf.keras.utils.image_dataset_from_directory(
        dataset_root, validation_split=0.2, subset="validation", seed=SEED,
        image_size=IMG_SIZE, batch_size=BATCH_SIZE, label_mode="int"
    )

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", num_classes, class_names)

# Cache and prefetch
def prepare(ds):
    return ds.cache().prefetch(AUTOTUNE)

train_ds = prepare(train_ds)
val_ds = prepare(val_ds)
# Out:
# Found 13642 files belonging to 14 classes.
# Found 98 files belonging to 14 classes.
# Classes: 14 ['astilbe', 'bellflower', 'black_eyed_susan', 'calendula', 'california_poppy', 'carnation', 'common_daisy', 'coreopsis', 'dandelion', 'iris', 'rose', 'sunflower', 'tulip', 'water_lily']

# %%
print(f"Nombre de classes : {num_classes}")
print(f"Noms des classes : {class_names}")

# Vérifier le nombre de lots dans les datasets
print(f"Nombre de lots dans train_ds : {tf.data.experimental.cardinality(train_ds).numpy()} (ou -1 si indéterminé)")
print(f"Nombre de lots dans val_ds : {tf.data.experimental.cardinality(val_ds).numpy()} (ou -1 si indéterminé)")

# Inspecter un lot d'images et d'étiquettes
for images, labels in train_ds.take(1):
    print(f"Forme des images dans un lot de train_ds : {images.shape}")
    print(f"Forme des étiquettes dans un lot de train_ds : {labels.shape}")
    break

for images, labels in val_ds.take(1):
    print(f"Forme des images dans un lot de val_ds : {images.shape}")
    print(f"Forme des étiquettes dans un lot de val_ds : {labels.shape}")
    break
# Out:
# Nombre de classes : 14
# Noms des classes : ['astilbe', 'bellflower', 'black_eyed_susan', 'calendula', 'california_poppy', 'carnation', 'common_daisy', 'coreopsis', 'dandelion', 'iris', 'rose', 'sunflower', 'tulip', 'water_lily']
# Nombre de lots dans train_ds : 427 (ou -1 si indéterminé)
# Nombre de lots dans val_ds : 4 (ou -1 si indéterminé)
# Forme des images dans un lot de train_ds : (32, 32, 32, 3)
# Forme des étiquettes dans un lot de train_ds : (32,)
# Forme des images dans un lot de val_ds : (32, 32, 32, 3)
# Forme des étiquettes dans un lot de val_ds : (32,)

# %%
# PREFILLED: just execute — count images per class by scanning directory
from collections import Counter
import os

def count_images_per_class(root):
    counts = {}
    root = Path(root)
    for cls in class_names:
        folder = next((p for p in root.rglob(cls) if p.is_dir()), None)
        if folder is None:
            folder = root / cls
            if not folder.exists():
                counts[cls] = None
                continue
        img_count = sum(1 for p in folder.rglob("*") if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp", ".gif"})
        counts[cls] = img_count
    return counts

base_dir = train_dir if layout == "provided_split" else base
counts = count_images_per_class(base_dir)
counts
# Out:
# {'astilbe': 726,
#  'bellflower': 872,
#  'black_eyed_susan': 986,
#  'calendula': 1011,
#  'california_poppy': 1021,
#  'carnation': 924,
#  'common_daisy': 978,
#  'coreopsis': 1035,
#  'dandelion': 1038,
#  'iris': 1041,
#  'rose': 986,
#  'sunflower': 1013,
#  'tulip': 1034,
#  'water_lily': 977}

# %%
# To-Do: implement visualize_images to display a 3x3 grid for each class
# Hints:
# def visualize_images(dataset, class_names, per_class=9):
#     # iterate batches, collect images by label until you have 9 per class
#     # for each class, plot a 3x3 grid and set the figure suptitle to the class name
#     pass

# %%
import matplotlib.pyplot as plt

def visualize_images(dataset, class_names, per_class=9):
    class_images = {name: [] for name in class_names}
    images_collected = {name: 0 for name in class_names}

    for images, labels in dataset:
        for i in range(len(images)):
            label_idx = int(labels[i].numpy())
            class_name = class_names[label_idx]
            if images_collected[class_name] < per_class:
                class_images[class_name].append(images[i].numpy().astype('uint8'))
                images_collected[class_name] += 1

        if all(images_collected[name] >= per_class for name in class_names):
            break

    for class_name, imgs in class_images.items():
        if not imgs:
            continue

        plt.figure(figsize=(8, 8))
        plt.suptitle(class_name, fontsize=16)
        for i in range(min(per_class, len(imgs))):
            plt.subplot(3, 3, i + 1)
            plt.imshow(imgs[i])
            plt.axis('off')
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()

# %%
# To-Do: After you implement `visualize_images`, run it on a small subset to verify class distributions visually.
# Here's how you can call the visualize_images function:
# For demonstration, you might want to create a smaller dataset or limit the number of classes shown
# If you have a large number of classes, showing all at once might be too much.

# Example usage:
# To visualize a few classes, you can create a subset of your train_ds
# For simplicity, let's just call it on the full train_ds, but be aware it might show many plots

print("Visualizing images from the training dataset...")
# You might want to take a smaller, unbatched dataset for visualization
# For efficiency, we will use a small subset of the training data. If you want to see more, adjust `take`.
visual_ds = train_ds.unbatch().take(num_classes * 9) # Take 9 images per class, for all classes
visual_ds = visual_ds.batch(BATCH_SIZE) # Re-batch for visualize_images function compatibility

visualize_images(visual_ds, class_names, per_class=9)
# Out:
# Visualizing images from the training dataset...

# %% [markdown]
# **To-Do:** After you implement `visualize_images`, run it on a small subset to verify class distributions visually.

# %% [markdown]
# **To-Do (written):** Analyze expected challenges for classification in 4 to 6 sentences. Mention similar color palettes across species, intra class variation due to background and lighting, and class imbalance if present.

# %% [markdown]
# **Learning point**
# Vision models learn features from texture, color, and shape. Dataset bias and imbalance can dominate results without careful preprocessing and evaluation.

# %% [markdown]
# ## Part 2. Model architecture design
#
# **As stated in the exercises**
# Start from the provided model. Experiment with the number of convolutional layers, filters, kernel sizes, max pooling layers. Try different dense layers and dropout. Consider Batch Normalization. Justify your architectural choices.

# %%
# PREFILLED: just execute — baseline model scaffold
from tensorflow.keras import models

def build_baseline(num_classes):
    model = models.Sequential([
        layers.Input(shape=(*IMG_SIZE, 3)),
        layers.Rescaling(1./255),  # safety if datasets were not normalized
        layers.Conv2D(32, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation="softmax")
    ])
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

baseline = build_baseline(num_classes)
baseline.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 14)             │         1,806 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 357,326 (1.36 MB)
#  Trainable params: 357,326 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# To-Do: create an improved architecture variant
# Suggestions:
# - Add BatchNormalization after Conv2D or Dense
# - Try kernel sizes 5x5 in early layers
# - Increase filters progressively 32->64->128->256
# - Adjust Dropout to 0.4
# def build_variant(num_classes):
#     pass
# model_variant = build_variant(num_classes)
# model_variant.summary()

# %% [markdown]
# **To-Do (written):** Justify your chosen layers and parameters in 4 to 6 sentences. Refer to receptive field growth, normalization stabilizing training, and dropout for regularization.

# %% [markdown]
# ## Part 3. Hyperparameter tuning
#
# **As stated in the exercises**
# Experiment with optimizers, learning rate, batch size, and optionally learning rate scheduling or early stopping. Track experiments and results. Report the best combination.

# %%
# PREFILLED: just execute — utilities for training and plotting
import time

def fit_model(model, train_ds, val_ds, epochs=5, callbacks=None):
    t0 = time.time()
    history = model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=callbacks, verbose=2)
    dt = time.time() - t0
    return history, dt

def plot_curves(history, title="Training"):
    plt.figure(figsize=(6,4))
    plt.plot(history.history.get("accuracy", []), label="acc")
    plt.plot(history.history.get("val_accuracy", []), label="val_acc")
    plt.title(title); plt.xlabel("epoch"); plt.ylabel("accuracy"); plt.legend(); plt.tight_layout(); plt.show()
    plt.figure(figsize=(6,4))
    plt.plot(history.history.get("loss", []), label="loss")
    plt.plot(history.history.get("val_loss", []), label="val_loss")
    plt.title(title); plt.xlabel("epoch"); plt.ylabel("loss"); plt.legend(); plt.tight_layout(); plt.show()

# %%
#To-Do: run a few experiments
#Example search space
opts = [
  ("adam", 1e-3, 32),
  ("adam", 5e-4, 32),
  ("rmsprop", 1e-3, 32),
  ("sgd", 1e-2, 64),
]
results = []
for opt_name, lr, batch in opts:
    # rebuild model each time
    model = build_baseline(num_classes)  # or your variant
    if opt_name == "adam":
        optimizer = tf.keras.optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        optimizer = tf.keras.optimizers.RMSprop(lr)
    else:
        optimizer = tf.keras.optimizers.SGD(lr, momentum=0.9, nesterov=True)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    cb = [tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)]
    hist, dur = fit_model(model, train_ds, val_ds, epochs=8, callbacks=cb)
    best_val = max(hist.history["val_accuracy"])
    results.append({"opt": opt_name, "lr": lr, "batch": batch, "best_val_acc": float(best_val), "time_s": round(dur,1)})
results
# Out:
# Epoch 1/8
# 427/427 - 13s - 29ms/step - accuracy: 0.3508 - loss: 1.8404 - val_accuracy: 0.5000 - val_loss: 1.4074
# Epoch 2/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5210 - loss: 1.3705 - val_accuracy: 0.5714 - val_loss: 1.1154
# Epoch 3/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5915 - loss: 1.1764 - val_accuracy: 0.6531 - val_loss: 0.9337
# Epoch 4/8
# 427/427 - 3s - 6ms/step - accuracy: 0.6380 - loss: 1.0318 - val_accuracy: 0.7143 - val_loss: 0.8394
# Epoch 5/8
# 427/427 - 3s - 7ms/step - accuracy: 0.6831 - loss: 0.9051 - val_accuracy: 0.6939 - val_loss: 0.8135
# Epoch 6/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7178 - loss: 0.8138 - val_accuracy: 0.7347 - val_loss: 0.7500
# Epoch 7/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7493 - loss: 0.7236 - val_accuracy: 0.7653 - val_loss: 0.7420
# Epoch 8/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7797 - loss: 0.6249 - val_accuracy: 0.7449 - val_loss: 0.7938
# Epoch 1/8
# 427/427 - 4s - 11ms/step - accuracy: 0.3192 - loss: 1.9411 - val_accuracy: 0.4490 - val_loss: 1.5155
# Epoch 2/8
# 427/427 - 3s - 7ms/step - accuracy: 0.4713 - loss: 1.5153 - val_accuracy: 0.5102 - val_loss: 1.3174
# Epoch 3/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5380 - loss: 1.3267 - val_accuracy: 0.6020 - val_loss: 1.1460
# Epoch 4/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5833 - loss: 1.1958 - val_accuracy: 0.6429 - val_loss: 1.0354
# Epoch 5/8
# 427/427 - 3s - 7ms/step - accuracy: 0.6274 - loss: 1.0863 - val_accuracy: 0.6735 - val_loss: 0.9333
# Epoch 6/8
# 427/427 - 3s - 7ms/step - accuracy: 0.6561 - loss: 1.0014 - val_accuracy: 0.6939 - val_loss: 0.8559
# Epoch 7/8
# 427/427 - 3s - 7ms/step - accuracy: 0.6789 - loss: 0.9330 - val_accuracy: 0.6735 - val_loss: 0.9420
# Epoch 8/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7054 - loss: 0.8564 - val_accuracy: 0.7245 - val_loss: 0.7610
# Epoch 1/8
# 427/427 - 4s - 9ms/step - accuracy: 0.3349 - loss: 1.8785 - val_accuracy: 0.3878 - val_loss: 1.5125
# Epoch 2/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5046 - loss: 1.4308 - val_accuracy: 0.4694 - val_loss: 1.3315
# Epoch 3/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5853 - loss: 1.2159 - val_accuracy: 0.5510 - val_loss: 1.1797
# Epoch 4/8
# 427/427 - 3s - 7ms/step - accuracy: 0.6371 - loss: 1.0636 - val_accuracy: 0.5714 - val_loss: 1.1364
# Epoch 5/8
# 427/427 - 3s - 8ms/step - accuracy: 0.6847 - loss: 0.9334 - val_accuracy: 0.6224 - val_loss: 0.9372
# Epoch 6/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7207 - loss: 0.8265 - val_accuracy: 0.6837 - val_loss: 0.8621
# Epoch 7/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7573 - loss: 0.7258 - val_accuracy: 0.6531 - val_loss: 0.8417
# Epoch 8/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7822 - loss: 0.6358 - val_accuracy: 0.6837 - val_loss: 0.8839
# Epoch 1/8
# 427/427 - 4s - 9ms/step - accuracy: 0.3053 - loss: 1.9536 - val_accuracy: 0.4694 - val_loss: 1.5585
# Epoch 2/8
# 427/427 - 3s - 7ms/step - accuracy: 0.4530 - loss: 1.5395 - val_accuracy: 0.4082 - val_loss: 1.3729
# Epoch 3/8
# 427/427 - 3s - 8ms/step - accuracy: 0.5218 - loss: 1.3553 - val_accuracy: 0.5408 - val_loss: 1.2101
# Epoch 4/8
# 427/427 - 3s - 7ms/step - accuracy: 0.5765 - loss: 1.2130 - val_accuracy: 0.5918 - val_loss: 1.1209
# Epoch 5/8
# 427/427 - 3s - 8ms/step - accuracy: 0.6174 - loss: 1.0914 - val_accuracy: 0.6939 - val_loss: 0.9824
# Epoch 6/8
# 427/427 - 3s - 8ms/step - accuracy: 0.6554 - loss: 0.9879 - val_accuracy: 0.6531 - val_loss: 0.9522
# Epoch 7/8
# 427/427 - 3s - 7ms/step - accuracy: 0.6882 - loss: 0.8942 - val_accuracy: 0.6633 - val_loss: 1.0059
# Epoch 8/8
# 427/427 - 3s - 7ms/step - accuracy: 0.7187 - loss: 0.8035 - val_accuracy: 0.6837 - val_loss: 1.0131
# [{'opt': 'adam',
#   'lr': 0.001,
#   'batch': 32,
#   'best_val_acc': 0.7653061151504517,
#   'time_s': 32.7},
#  {'opt': 'adam',
#   'lr': 0.0005,
#   'batch': 32,
#   'best_val_acc': 0.7244898080825806,
#   'time_s': 25.0},
#  {'opt': 'rmsprop',
#   'lr': 0.001,
#   'batch': 32,
#   'best_val_acc': 0.6836734414100647,
#   'time_s': 24.5},
#  {'opt': 'sgd',
#   'lr': 0.01,
#   'batch': 64,
#   'best_val_acc': 0.6938775777816772,
#   'time_s': 26.0}]

# %% [markdown]
# **To-Do (written):** Report the best hyperparameters you found and briefly explain why they might work well for this dataset.

# %% [markdown]
# ## Part 4. Data augmentation
#
# **As stated in the exercises**
# Implement data augmentation using `ImageDataGenerator`. Explore rotation, flipping, zooming, shifting, and shearing. Determine which augmentations help most and explain why.

# %% [markdown]
# **Guidance**
# Since we used `image_dataset_from_directory` above, you can either:
# Option A. Rebuild input using `ImageDataGenerator.flow_from_directory` on the training directory.
# Option B. Keep the tf.data pipeline and apply Keras preprocessing layers such as `RandomFlip`, `RandomRotation`.
# The exercises asks for `ImageDataGenerator`, so Option A shows that path.

# %%
# To-Do: build an ImageDataGenerator pipeline (Option A)
# from keras.preprocessing.image import ImageDataGenerator
# train_dir = next((p for p in Path(base).iterdir() if p.name.lower()=='train'), None)
# if train_dir is None:
#     train_dir = base  # if single root
# datagen = ImageDataGenerator(
#     rescale=1./255,
#     rotation_range=20,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.1,
#     horizontal_flip=True,
#     fill_mode='nearest',
#     validation_split=0.2
# )
# flow_train = datagen.flow_from_directory(train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
#                                         class_mode='sparse', subset='training', seed=SEED)
# flow_val = datagen.flow_from_directory(train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE,
#                                       class_mode='sparse', subset='validation', seed=SEED)
# model_aug = build_baseline(num_classes)  # or your variant
# hist_aug = model_aug.fit(flow_train, validation_data=flow_val, epochs=8, verbose=2)
# plot_curves(hist_aug, title='Augmented training')

# %% [markdown]
# **Learning point**
# Augmentation encodes invariances like rotation and translation. It increases effective sample diversity which often reduces overfitting.

# %% [markdown]
# ## Part 5. Performance evaluation and analysis
#
# **As stated in the exercises**
# Plot training and validation curves. Compute precision, recall, F1, and a confusion matrix. Visualize predictions on a test set and analyze misclassifications.

# %%
# PREFILLED: just execute — helpers for evaluation on a dataset
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

def collect_preds(model, ds):
    y_true = []
    y_prob = []
    for xb, yb in ds:
        pr = model.predict(xb, verbose=0)
        y_prob.append(pr)
        y_true.append(yb.numpy())
    y_true = np.concatenate(y_true)
    y_prob = np.concatenate(y_prob)
    if y_prob.ndim == 2 and y_prob.shape[1] > 1:
        y_pred = y_prob.argmax(axis=1)
    else:
        y_pred = (y_prob.ravel() >= 0.5).astype(int)
    return y_true, y_pred, y_prob

def plot_confusion(cm, labels):
    plt.figure(figsize=(6,6))
    plt.imshow(cm)
    plt.title("Confusion matrix")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    ticks = np.arange(len(labels))
    plt.xticks(ticks, labels, rotation=90)
    plt.yticks(ticks, labels)
    plt.tight_layout()
    plt.show()

# %%
# To-Do: evaluate your best model on val_ds
best_model = model_aug or model_variant or baseline
y_true, y_pred, y_prob = collect_preds(best_model, val_ds)
print(classification_report(y_true, y_pred, target_names=class_names, digits=3))
cm = confusion_matrix(y_true, y_pred)
plot_confusion(cm, class_names)
# Out:
#                   precision    recall  f1-score   support
#
#          astilbe      0.000     0.000     0.000         7
#       bellflower      0.000     0.000     0.000         7
# black_eyed_susan      0.000     0.000     0.000         7
#        calendula      0.000     0.000     0.000         7
# california_poppy      0.000     0.000     0.000         7
#        carnation      0.000     0.000     0.000         7
#     common_daisy      0.000     0.000     0.000         7
#        coreopsis      0.000     0.000     0.000         7
#        dandelion      0.000     0.000     0.000         7
#             iris      0.000     0.000     0.000         7
#             rose      0.000     0.000     0.000         7
#        sunflower      0.073     1.000     0.136         7
#            tulip      0.000     0.000     0.000         7
#       water_lily      0.000     0.000     0.000         7
#
#         accuracy                          0.071        98
#        macro avg      0.005     0.071     0.010        98
#     weighted avg      0.005     0.071     0.010        98
# c:\Users\meles\Documents\TTA_DI_BootCamp_Gilles-Chris_MAKE\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\meles\Documents\TTA_DI_BootCamp_Gilles-Chris_MAKE\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\meles\Documents\TTA_DI_BootCamp_Gilles-Chris_MAKE\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# To-Do: visualize a few predictions and inspect errors
import random
take = 12
imgs, labels = next(iter(val_ds.unbatch().batch(take)))
probs = best_model.predict(imgs, verbose=0)
preds = probs.argmax(axis=1)
for i in range(take):
    plt.figure(figsize=(2.5,2.5))
    plt.imshow(imgs[i].numpy().astype('uint8'))
    t = f"true: {class_names[int(labels[i])]}\npred: {class_names[int(preds[i])]}"
    plt.title(t)
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **To-Do (written):** Identify classes that your model finds difficult. Explain possible causes such as similar morphology or color, or small sample counts.

# %% [markdown]
# ## Part 6. Model saving and deployment (optional)
#
# **As stated in the exercises**
# Save your trained model in `.h5` or SavedModel format. Optionally consider web or cloud deployment.

# %%
# To-Do: save your best model
# best_model.save("./data/flower_cnn_savedmodel")  # SavedModel directory
# best_model.save("./data/flower_cnn.h5")  # H5 file
# print("Saved to ./data/")
