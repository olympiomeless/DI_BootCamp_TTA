# %% [markdown]
# # Exercises XP: Open-Source LLM Strategy (Student)
# Use this guided notebook and fill each TODO. Run it in Colab if you prefer; GPU not required unless you try optional model runs.

# %% [markdown]
# ## What you'll learn
# - Identify degrees of openness in LLMs and what each enables.
# - Understand and compare open-source licenses.
# - Assess strengths/trade-offs of open LLMs for specific constraints (CPU, math, multilingual).
# - Evaluate which models fit given hardware and licensing needs.
# - Use open tools/leaderboards to guide model selection.
# - Plan deployment trade-offs (local vs. cloud).

# %% [markdown]
# ## What you will create
# - Comparative LLM openness analysis (table + paragraph + healthcare prompt answer).
# - Licensing compatibility checklist for SaaS products.
# - Quiz-style reflection on LLM selection.
# - Local deployment readiness checklist + upgrade notes.
# - Benchmark-based model match guide.
# - Hardware upgrade plan / cost-benefit comparison (local vs. cloud).

# %% [markdown]
# ## Exercise 1: Open Source Levels Reflection
# **Use:** Fully Open, Weights Released, Architecture Only; model components; fine-tuning/domain adaptation; healthcare compliance.
#
# **Step-by-step**
# 1) Gather definitions for the three openness levels.
# 2) Identify key characteristics (what is open; what you can/cannot do).
# 3) Compare side by side in a table (what's open vs. impact).
# 4) Write a 3?5 sentence comparative paragraph.
# 5) Answer the healthcare prompt (1?2 sentences) about retraining on clinical data.
#
# **Deliverables:** paragraph + healthcare answer.

# %%
# TODO: capture definitions and key characteristics
open_source_levels = {
    "Fully Open": {
        "definition": "TODO: define Fully Open",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
    "Weights Released": {
        "definition": "TODO: define Weights Released",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
    "Architecture Only": {
        "definition": "TODO: define Architecture Only",
        "what_is_open": ["TODO", "TODO"],
        "what_you_can_do": ["TODO", "TODO"],
        "what_you_cannot_do": ["TODO", "TODO"],
    },
}
open_source_levels
# Out:
# {'Fully Open': {'definition': 'TODO: define Fully Open',
#   'what_is_open': ['TODO', 'TODO'],
#   'what_you_can_do': ['TODO', 'TODO'],
#   'what_you_cannot_do': ['TODO', 'TODO']},
#  'Weights Released': {'definition': 'TODO: define Weights Released',
#   'what_is_open': ['TODO', 'TODO'],
#   'what_you_can_do': ['TODO', 'TODO'],
#   'what_you_cannot_do': ['TODO', 'TODO']},
#  'Architecture Only': {'definition': 'TODO: define Architecture Only',
#   'what_is_open': ['TODO', 'TODO'],
#   'what_you_can_do': ['TODO', 'TODO'],
#   'what_you_cannot_do': ['TODO', 'TODO']}}

# %%
# TODO: fill the comparison table (keep markdown formatting)
comparison_table = """| Openness level | What's open? | Impact on retraining/modifying |
| --- | --- | --- |
| Fully Open | TODO | TODO |
| Weights Released | TODO | TODO |
| Architecture Only | TODO | TODO |"""
print(comparison_table)
# Out:
# | Openness level | What's open? | Impact on retraining/modifying |
# | --- | --- | --- |
# | Fully Open | TODO | TODO |
# | Weights Released | TODO | TODO |
# | Architecture Only | TODO | TODO |

# %%
# TODO: 3?5 sentence comparative paragraph
comparative_paragraph = """TODO"""
print(comparative_paragraph)
# Out:
# TODO

# %%
# TODO: 1?2 sentence healthcare prompt answer
healthcare_prompt_answer = """TODO"""
print(healthcare_prompt_answer)
# Out:
# TODO

# %% [markdown]
# ## Exercise 2: License Check for SaaS Use
# **Use:** HF model pages; permissive vs. copyleft; commercial clauses; restrictions (MAU caps, attribution, export controls).
#
# **Step-by-step**
# 1) Select two HF models (e.g., Mistral-7B-Instruct, Llama-2-7b-chat-hf) and note URLs.
# 2) Locate the License field and copy the name.
# 3) Determine if commercial use is allowed/restricted/prohibited; note conditions.
# 4) Identify extra restrictions (MAU caps, attribution, export/geography).
# 5) Build the markdown checklist with your findings.
#
# **Deliverables:** model names + URLs + completed checklist.

# %%
# TODO: record model metadata from the HF pages
license_checklist = [
    {
        "model": "mistralai/Mistral-7B-Instruct-v0.3",
        "url": "TODO: add model URL",
        "license": "TODO: e.g., Apache 2.0",
        "commercial_use": "TODO: Yes / No / Conditional",
        "restrictions": ["TODO", "TODO"],
    },
    {
        "model": "meta-llama/Llama-2-7b-chat-hf",
        "url": "TODO: add model URL",
        "license": "TODO: e.g., Llama 2 Community License",
        "commercial_use": "TODO: Yes / No / Conditional",
        "restrictions": ["TODO", "TODO"],
    },
]
license_checklist
# Out:
# [{'model': 'mistralai/Mistral-7B-Instruct-v0.3',
#   'url': 'TODO: add model URL',
#   'license': 'TODO: e.g., Apache 2.0',
#   'commercial_use': 'TODO: Yes / No / Conditional',
#   'restrictions': ['TODO', 'TODO']},
#  {'model': 'meta-llama/Llama-2-7b-chat-hf',
#   'url': 'TODO: add model URL',
#   'license': 'TODO: e.g., Llama 2 Community License',
#   'commercial_use': 'TODO: Yes / No / Conditional',
#   'restrictions': ['TODO', 'TODO']}]

# %% [markdown]
# ### Checklist template (fill and keep in markdown)
# - [ ] **Model 1**
#   - Type of license:
#     - [ ] License name
#   - Commercial use allowed:
#     - [ ] Yes / No / Conditional
#   - Restrictions:
#     - [ ] Restriction #1
#     - [ ] Restriction #2
# - [ ] **Model 2**
#   - Type of license:
#     - [ ] License name
#   - Commercial use allowed:
#     - [ ] Yes / No / Conditional
#   - Restrictions:
#     - [ ] Restriction #1
#     - [ ] Restriction #2

# %% [markdown]
# ## Exercise 3: LLM Matchmaker Challenge
# **Use:** CPU inference, low-end laptops, multilingual needs; HF filters; size <=7B; benchmarks (BoolQ, GSM8K, FLORES-200).
#
# **Step-by-step**
# 1) Analyze team needs (LegalTech CPU logic; EdTech math/logic low-end; Global NGO multilingual >=5 langs).
# 2) Apply HF filters (cpu/quantized, logic/math/multilingual tags, size <=7B).
# 3) List 3?5 candidates per team with params/arch/quantization/benchmarks.
# 4) Compare top 2 per team and pick the best model with justification.
# 5) Fill the table with your picks.
#
# **Deliverables:** filter summary + filled picks table.

# %%
# TODO: jot down search filters or URLs for each team
filters_by_team = {
    "LegalTech": ["TODO: e.g., text-generation, cpu, gguf, logic/boolq, <=7B"],
    "EdTech": ["TODO: e.g., math/gsm8k tag, cpu/quantized, <=7B (prefer <=4B)"],
    "Global NGO": ["TODO: e.g., multilingual tag, cpu/gguf, <=7B"],
}
filters_by_team
# Out:
# {'LegalTech': ['TODO: e.g., text-generation, cpu, gguf, logic/boolq, <=7B'],
#  'EdTech': ['TODO: e.g., math/gsm8k tag, cpu/quantized, <=7B (prefer <=4B)'],
#  'Global NGO': ['TODO: e.g., multilingual tag, cpu/gguf, <=7B']}

# %%
# TODO: candidate lists per team (3?5 each)
candidates_by_team = {
    "LegalTech": [
        {"model": "TODO", "params_b": "", "arch": "", "optimization": "", "benchmarks": ""},
    ],
    "EdTech": [
        {"model": "TODO", "params_b": "", "arch": "", "optimization": "", "benchmarks": ""},
    ],
    "Global NGO": [
        {"model": "TODO", "params_b": "", "arch": "", "optimization": "", "benchmarks": ""},
    ],
}
candidates_by_team
# Out:
# {'LegalTech': [{'model': 'TODO',
#    'params_b': '',
#    'arch': '',
#    'optimization': '',
#    'benchmarks': ''}],
#  'EdTech': [{'model': 'TODO',
#    'params_b': '',
#    'arch': '',
#    'optimization': '',
#    'benchmarks': ''}],
#  'Global NGO': [{'model': 'TODO',
#    'params_b': '',
#    'arch': '',
#    'optimization': '',
#    'benchmarks': ''}]}

# %%
# TODO: final picks table (keep markdown formatting)
matchmaker_table = """| Team | Needs | Your Pick |
| --- | --- | --- |
| LegalTech | Fast model for logic-heavy chatbot on CPU | TODO |
| EdTech | Logic/math-focused LLM on low-end laptops | TODO |
| Global NGO | Model that speaks 5+ languages well | TODO |"""
print(matchmaker_table)
# Out:
# | Team | Needs | Your Pick |
# | --- | --- | --- |
# | LegalTech | Fast model for logic-heavy chatbot on CPU | TODO |
# | EdTech | Logic/math-focused LLM on low-end laptops | TODO |
# | Global NGO | Model that speaks 5+ languages well | TODO |

# %% [markdown]
# ## Exercise 4: Local Readiness Audit
# **Use:** RAM/disk/OS; llama.cpp requirements (AVX/SSE, cmake/make/gcc/clang); quantized formats (GGUF).
#
# **Step-by-step**
# 1) Gather system specs (RAM, free disk, OS type/version).
# 2) Fill the audit table and mark ?/?.
# 3) Check llama.cpp readiness (instruction sets, compilers, build tools).
# 4) Identify upgrade needs for each ?.
#
# **Deliverables:** filled table + upgrade summary.

# %%
# TODO: your measured system specs
system_specs = {
    "ram_gb": "TODO",
    "free_disk_gb": "TODO",
    "os": "TODO",
}
system_specs
# Out:
# {'ram_gb': 'TODO', 'free_disk_gb': 'TODO', 'os': 'TODO'}

# %%
# TODO: readiness table (keep markdown formatting)
readiness_table = """| Requirement | Your System Specs | Meets Requirement? |
| --- | --- | --- |
| RAM (>= 16 GB) | TODO | ? / ? |
| Free Disk Space (>= 40 GB) | TODO | ? / ? |
| OS (Linux/WSL2) | TODO | ? / ? |"""
print(readiness_table)
# Out:
# | Requirement | Your System Specs | Meets Requirement? |
# | --- | --- | --- |
# | RAM (>= 16 GB) | TODO | ? / ? |
# | Free Disk Space (>= 40 GB) | TODO | ? / ? |
# | OS (Linux/WSL2) | TODO | ? / ? |

# %%
# TODO: llama.cpp readiness notes
llama_cpp_readiness = {
    "cpu_instruction_support": "TODO: e.g., AVX2 / AVX-512 / NEON",
    "tooling": ["TODO: cmake", "TODO: gcc/clang"],
    "other_requirements": "TODO",
}
llama_cpp_readiness
# Out:
# {'cpu_instruction_support': 'TODO: e.g., AVX2 / AVX-512 / NEON',
#  'tooling': ['TODO: cmake', 'TODO: gcc/clang'],
#  'other_requirements': 'TODO'}

# %%
# TODO: upgrade or mitigation actions
upgrade_actions = ["TODO", "TODO"]
upgrade_actions
# Out:
# ['TODO', 'TODO']

# %% [markdown]
# ## Exercise 5: Benchmark-Based Model Explorer
# **Use:** Open LLM Leaderboard; HellaSwag and MMLU scores; license types; use-case mapping.
#
# **Step-by-step**
# 1) Pick three models from the leaderboard with different strengths (high HellaSwag, high MMLU, balanced).
# 2) Record HellaSwag, MMLU, license, and ideal use case.
# 3) Fill the comparison table.
# 4) Optional: 1?2 sentence reflection on why benchmarks matter.
# 5) Quiz-style reflection: write 3 short Q&A items about choosing models for different constraints.
#
# **Deliverables:** model list + filled table + quiz-style reflection (+ optional reflection paragraph).

# %%
leaderboard_models = [
    {"model": "Model-A", "url": "https://huggingface.co/models/Model-A", "hellaswag": "XX.X", "mmlu": "YY.Y", "license": "Apache 2.0", "ideal_use_case": "Commonsense Q&A agent"},
    {"model": "Model-B", "url": "https://huggingface.co/models/Model-B", "hellaswag": "XX.X", "mmlu": "YY.Y", "license": "MIT License", "ideal_use_case": "Academic question tutor"},
    {"model": "Model-C", "url": "https://huggingface.co/models/Model-C", "hellaswag": "XX.X", "mmlu": "YY.Y", "license": "CC BY 4.0", "ideal_use_case": "Multilingual assistant"},
]
leaderboard_models
# Out:
# [{'model': 'Model-A',
#   'url': 'https://huggingface.co/models/Model-A',
#   'hellaswag': 'XX.X',
#   'mmlu': 'YY.Y',
#   'license': 'Apache 2.0',
#   'ideal_use_case': 'Commonsense Q&A agent'},
#  {'model': 'Model-B',
#   'url': 'https://huggingface.co/models/Model-B',
#   'hellaswag': 'XX.X',
#   'mmlu': 'YY.Y',
#   'license': 'MIT License',
#   'ideal_use_case': 'Academic question tutor'},
#  {'model': 'Model-C',
#   'url': 'https://huggingface.co/models/Model-C',
#   'hellaswag': 'XX.X',
#   'mmlu': 'YY.Y',
#   'license': 'CC BY 4.0',
#   'ideal_use_case': 'Multilingual assistant'}]

# %%
benchmark_table = f"""| Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
| --- | --- | --- | --- | --- |
| {leaderboard_models[0]['model']} | {leaderboard_models[0]['hellaswag']} | {leaderboard_models[0]['mmlu']} | {leaderboard_models[0]['license']} | {leaderboard_models[0]['ideal_use_case']} |
| {leaderboard_models[1]['model']} | {leaderboard_models[1]['hellaswag']} | {leaderboard_models[1]['mmlu']} | {leaderboard_models[1]['license']} | {leaderboard_models[1]['ideal_use_case']} |
| {leaderboard_models[2]['model']} | {leaderboard_models[2]['hellaswag']} | {leaderboard_models[2]['mmlu']} | {leaderboard_models[2]['license']} | {leaderboard_models[2]['ideal_use_case']} |"""
print(benchmark_table)
# Out:
# | Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
# | --- | --- | --- | --- | --- |
# | Model-A | XX.X | YY.Y | Apache 2.0 | Commonsense Q&A agent |
# | Model-B | XX.X | YY.Y | MIT License | Academic question tutor |
# | Model-C | XX.X | YY.Y | CC BY 4.0 | Multilingual assistant |

# %% [markdown]
# ### Optional reflection
# 1?2 sentences on why benchmarks?not hype?should guide model choice.

# %%
# TODO: quiz-style reflection (3 short Q&A items on model selection)
quiz_reflection = [
    {"question": "TODO", "answer": "TODO"},
    {"question": "TODO", "answer": "TODO"},
    {"question": "TODO", "answer": "TODO"},
]
quiz_reflection
# Out:
# [{'question': 'TODO', 'answer': 'TODO'},
#  {'question': 'TODO', 'answer': 'TODO'},
#  {'question': 'TODO', 'answer': 'TODO'}]

# %% [markdown]
# ## Exercise 6: Cloud vs. Local Deployment Plan
# **Use:** local vs. cloud cost/latency/scalability/security/maintenance; optional Colab timing.
#
# **Step-by-step**
# 1) Draft 5 bullets pairing local vs. cloud pros/cons.
# 2) Optional: run a 7B model on Colab; note model and response time.
# 3) Summarize Colab observation if you ran it.
#
# **Deliverables:** 5 bullets; optional Colab report (model + time).

# %%
pros_and_cons = [
    "Local: ✔️ Low latency & direct control over hardware. ❌ High upfront hardware cost & maintenance burden.",
    "Cloud: ✔️ Scalability on demand & access to specialized GPUs. ❌ Potential for vendor lock-in & recurring costs.",
    "Local: ✔️ Enhanced data privacy and security (if isolated). ❌ Limited compute resources for large models.",
    "Cloud: ✔️ Reduced operational overhead & no cold starts for pre-provisioned instances. ❌ Network latency can impact real-time applications.",
    "Local: ✔️ Ideal for development and small-scale applications. ❌ Difficult to manage for large-scale production deployments.",
]
pros_and_cons
# Out:
# ['Local: ✔️ Low latency & direct control over hardware. ❌ High upfront hardware cost & maintenance burden.',
#  'Cloud: ✔️ Scalability on demand & access to specialized GPUs. ❌ Potential for vendor lock-in & recurring costs.',
#  'Local: ✔️ Enhanced data privacy and security (if isolated). ❌ Limited compute resources for large models.',
#  'Cloud: ✔️ Reduced operational overhead & no cold starts for pre-provisioned instances. ❌ Network latency can impact real-time applications.',
#  'Local: ✔️ Ideal for development and small-scale applications. ❌ Difficult to manage for large-scale production deployments.']

# %%
# !pip install transformers accelerate

# %% [markdown]
# ### Hugging Face Authentication
#
# To access gated models like `meta-llama/Llama-2-7b-chat-hf`, you need to authenticate with Hugging Face. Please run the following cell and enter your Hugging Face token when prompted. You can generate a token from your Hugging Face settings page.

# %%
from huggingface_hub import login

login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>ILBX-ER3Z</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center><b style='color: red;'>Login failed: Device code expired (timeout). Please try again.</b></center>

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import time

model_name = "mistralai/Mistral-7B-Instruct-v0.2"  # Changed to an openly accessible model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", torch_dtype="auto")

inputs = tokenizer("Hello, world!", return_tensors="pt").to(model.device)
start = time.time()
outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0]))
print("Elapsed:", time.time() - start, "seconds")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.
# [transformers] Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> Hello, world!
#
# ...

# %%
# Optional: Colab timing note
colab_run = {
    "model_tested": "mistralai/Mistral-7B-Instruct-v0.2",
    "response_time_seconds": "TODO",
    "notes": "Attempted to run meta-llama/Llama-2-7b-chat-hf but it was gated. Switched to mistralai/Mistral-7B-Instruct-v0.2.",
}
colab_run
# Out:
# {'model_tested': 'mistralai/Mistral-7B-Instruct-v0.2',
#  'response_time_seconds': 'TODO',
#  'notes': 'Attempted to run meta-llama/Llama-2-7b-chat-hf but it was gated. Switched to mistralai/Mistral-7B-Instruct-v0.2.'}
